# %%
import matplotlib
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import os

# %%
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /Users/oliverinaldi/Documents/GitHub/IllusoryPitch/E2/data

# %%
import os

new_directory = "/Users/oliverinaldi/Documents/GitHub/IllusoryPitch/E2/data"
os.chdir(new_directory)

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_two = 2
ptwo = scores[scores['subject'] == partic_to_keep_two]
ptwo
# Out:
#     subject experimenter  version  jnd  difficulty  interval  hit_rate  \
# 45        2          JKP      1.0  4.0         1.0       425  0.865854
# 46        2          JKP      1.0  4.0         1.0       500  0.890244
# 47        2          JKP      1.0  4.0         1.0       575  0.841463
#
#      fa_rate  accuracy  perc_resp_low    dprime         C      rt
# 45  0.402439    0.7375         0.3625  1.354042 -0.429982  0.6250
# 46  0.378049    0.7625         0.3625  1.538436 -0.458608  0.5625
# 47  0.231707    0.8125         0.4625  1.733726 -0.133627  0.6000

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thr = 3
pthr = scores[scores['subject'] == partic_to_keep_thr]
pthr
# Out:
#      subject experimenter  version    jnd  difficulty  interval  hit_rate  \
# 108        3          JKP      1.0  7.125         1.0       425  0.865854
# 109        3          JKP      1.0  7.125         1.0       500  0.817073
# 110        3          JKP      1.0  7.125         1.0       575  0.792683
#
#       fa_rate  accuracy  perc_resp_low    dprime         C      rt
# 108  0.036585    0.9250         0.5500  2.898767  0.342381  1.0000
# 109  0.060976    0.8875         0.5625  2.450903  0.321184  0.9500
# 110  0.012195    0.9000         0.6000  3.066691  0.717580  0.8625

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_four = 4
pfour = scores[scores['subject'] == partic_to_keep_four]
pfour
# Out:
#      subject experimenter  version      jnd  difficulty  interval  hit_rate  \
# 171        4           MW      1.0  25.8125         1.0       425  0.792683
# 172        4           MW      1.0  25.8125         1.0       500  0.914634
# 173        4           MW      1.0  25.8125         1.0       575  0.841463
#
#       fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 171  0.036585    0.8875         0.5875  2.607530  0.487999  0.650
# 172  0.085366    0.9250         0.5000  2.739713 -0.000000  0.675
# 173  0.036585    0.9125         0.5625  2.792255  0.395637  0.750

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_fiv = 5
pfiv = scores[scores['subject'] == partic_to_keep_fiv]
pfiv
# Out:
#      subject experimenter  version    jnd  difficulty  interval  hit_rate  \
# 174        5          JKP      1.0  8.875         1.0       425  0.524390
# 175        5          JKP      1.0  8.875         1.0       500  0.865854
# 176        5          JKP      1.0  8.875         1.0       575  0.670732
#
#       fa_rate  accuracy  perc_resp_low    dprime         C      rt
# 174  0.134146    0.7000         0.6750  1.168178  0.522914  1.2625
# 175  0.085366    0.9000         0.5250  2.476859  0.131427  1.2000
# 176  0.109756    0.7875         0.6125  1.669761  0.392946  1.1625

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_six = 6
psix = scores[scores['subject'] == partic_to_keep_six]
psix
# Out:
#      subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 177        6           EM      1.0  4.4375         1.0       425  0.939024
# 178        6           EM      1.0  4.4375         1.0       500  0.914634
# 179        6           EM      1.0  4.4375         1.0       575  0.914634
#
#       fa_rate  accuracy  perc_resp_low    dprime         C      rt
# 177  0.134146    0.9125         0.4625  2.653638 -0.219816  1.1125
# 178  0.085366    0.9250         0.5000  2.739713 -0.000000  0.9125
# 179  0.036585    0.9500         0.5250  3.161621  0.210954  0.9750

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_sev = 7
psev = scores[scores['subject'] == partic_to_keep_sev]
psev
# Out:
#      subject experimenter  version   jnd  difficulty  interval  hit_rate  \
# 180        7          OMR      1.0  28.5         1.0       425  0.890244
# 181        7          OMR      1.0  28.5         1.0       500  0.768293
# 182        7          OMR      1.0  28.5         1.0       575  0.597561
#
#       fa_rate  accuracy  perc_resp_low    dprime         C      rt
# 180  0.280488    0.8125         0.4125  1.809219 -0.323217  1.0000
# 181  0.134146    0.8250         0.5500  1.840239  0.186884  1.1375
# 182  0.134146    0.7375         0.6375  1.354042  0.429982  1.1000

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_eig = 8
peig = scores[scores['subject'] == partic_to_keep_eig]
peig
# Out:
#      subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 183        8          OMR      1.0  6.8125         1.0       425  0.939024
# 184        8          OMR      1.0  6.8125         1.0       500  0.987805
# 185        8          OMR      1.0  6.8125         1.0       575  0.963415
#
#       fa_rate  accuracy  perc_resp_low    dprime         C      rt
# 183  0.109756    0.9250         0.4750  2.774462 -0.159405  1.6875
# 184  0.231707    0.8875         0.3875  2.984161 -0.758845  1.8125
# 185  0.134146    0.9250         0.4500  2.898767 -0.342381  1.5625

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_two = 2
ptwo = scores[scores['subject'] == partic_to_keep_two]
ptwo
# Out:
#     subject experimenter  version  jnd  difficulty  interval  hit_rate  \
# 45        2          JKP      1.0  4.0         1.0       425  0.865854
# 46        2          JKP      1.0  4.0         1.0       500  0.890244
# 47        2          JKP      1.0  4.0         1.0       575  0.841463
#
#      fa_rate  accuracy  perc_resp_low    dprime         C      rt
# 45  0.402439    0.7375         0.3625  1.354042 -0.429982  0.6250
# 46  0.378049    0.7625         0.3625  1.538436 -0.458608  0.5625
# 47  0.231707    0.8125         0.4625  1.733726 -0.133627  0.6000

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_nin = 9
pnin = scores[scores['subject'] == partic_to_keep_nin]
pnin
# Out:
#      subject experimenter  version   jnd  difficulty  interval  hit_rate  \
# 186        9          NaN      1.0  7.75         1.0       425  0.939024
# 187        9          NaN      1.0  7.75         1.0       500  0.890244
# 188        9          NaN      1.0  7.75         1.0       575  0.841463
#
#       fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 186  0.012195     0.975          0.525  3.797561  0.352145  1.100
# 187  0.012195     0.950          0.550  3.478752  0.511550  1.025
# 188  0.012195     0.925          0.575  3.251416  0.625218  1.125

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = ptwo[ptwo.difficulty == 1])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pthr[pthr.difficulty == 1])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pfour[pfour.difficulty == 1])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pfiv[pfiv.difficulty == 1])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = psix[psix.difficulty == 1])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = psev[psev.difficulty == 1])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = peig[peig.difficulty == 1])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pnin[pnin.difficulty == 1])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_ten = 10
pten = scores[scores['subject'] == partic_to_keep_ten]
pten
# Out:
#    subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 0       10          OMR      1.0  2.6875         1.0       425  0.768293
# 1       10          OMR      1.0  2.6875         1.0       500  0.792683
# 2       10          OMR      1.0  2.6875         1.0       575  0.743902
#
#     fa_rate  accuracy  perc_resp_low    dprime         C      rt
# 0  0.353659    0.7125         0.4375  1.108698 -0.178887  1.1375
# 1  0.256098    0.7750         0.4750  1.471189 -0.080171  1.1625
# 2  0.451220    0.6500         0.4000  0.778004 -0.266421  1.1375

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pten[pten.difficulty == 1])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_ele = 11
pele = scores[scores['subject'] == partic_to_keep_ele]
pele
# Out:
#    subject experimenter  version   jnd  difficulty  interval  hit_rate  \
# 3       11          OMR      1.0  12.5         1.0       425  0.963415
# 4       11          OMR      1.0  12.5         1.0       500  0.987805
# 5       11          OMR      1.0  12.5         1.0       575  0.963415
#
#     fa_rate  accuracy  perc_resp_low    dprime         C      rt
# 3  0.134146    0.9250         0.4500  2.898767 -0.342381  1.3000
# 4  0.036585    0.9875         0.4875  4.042690 -0.229581  0.9000
# 5  0.109756    0.9375         0.4625  3.019591 -0.281969  1.2125

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pele[pele.difficulty == 1])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twl = 12
ptwl = scores[scores['subject'] == partic_to_keep_twl]
ptwl
# Out:
#    subject experimenter  version    jnd  difficulty  interval  hit_rate  \
# 6       12           EM      1.0  5.625         1.0       425  0.987805
# 7       12           EM      1.0  5.625         1.0       500  0.914634
# 8       12           EM      1.0  5.625         1.0       575  0.914634
#
#     fa_rate  accuracy  perc_resp_low    dprime         C      rt
# 6  0.182927    0.9125         0.4125  3.155193 -0.673329  0.9625
# 7  0.207317    0.8625         0.4375  2.185622 -0.277045  1.0375
# 8  0.085366    0.9250         0.5000  2.739713 -0.000000  0.9500

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = ptwl[ptwl.difficulty == 1])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thir = 13
pthir = scores[scores['subject'] == partic_to_keep_thir]
pthir
# Out:
#     subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 9        13           MW      1.0  5.3125         1.0       425  0.548780
# 10       13           MW      1.0  5.3125         1.0       500  0.426829
# 11       13           MW      1.0  5.3125         1.0       575  0.670732
#
#      fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 9   0.231707    0.6625         0.6125  0.855817  0.305327  0.850
# 10  0.304878    0.5625         0.6375  0.325969  0.347437  0.900
# 11  0.207317    0.7375         0.5625  1.257700  0.186916  1.025

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pthir[pthir.difficulty == 1])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_for = 14
pfor = scores[scores['subject'] == partic_to_keep_for]
pfor
# Out:
#     subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 12       14           MW      1.0  6.4375         1.0       425  0.939024
# 13       14           MW      1.0  6.4375         1.0       500  0.987805
# 14       14           MW      1.0  6.4375         1.0       575  0.914634
#
#      fa_rate  accuracy  perc_resp_low    dprime         C      rt
# 12  0.085366    0.9375         0.4875  2.916492 -0.088389  0.7500
# 13  0.012195    1.0000         0.5000  4.501851 -0.000000  0.8000
# 14  0.012195    0.9625         0.5375  3.620782  0.440535  0.7625

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pfor[pfor.difficulty == 1])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_fi = 15
pfi = scores[scores['subject'] == partic_to_keep_fi]
pfi
# Out:
#     subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 15       15           MW      1.1  19.875         1.0       425  0.880952
# 16       15           MW      1.1  19.875         1.0       500  0.833333
# 17       15           MW      1.1  19.875         1.0       575  0.928571
# 18       15           MW      1.1  19.875         0.5       425  0.976190
# 19       15           MW      1.1  19.875         0.5       500  0.833333
# 20       15           MW      1.1  19.875         0.5       575  0.738095
#
#      fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 15  0.214286     0.850          0.450  1.971400 -0.194061  1.300
# 16  0.166667     0.850          0.500  1.934843 -0.000000  1.225
# 17  0.071429     0.950          0.500  2.930468 -0.000000  1.325
# 18  0.214286     0.900          0.400  2.772391 -0.594557  1.400
# 19  0.071429     0.900          0.550  2.432655  0.248906  1.375
# ...

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pfi[pfi.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = pfi[pfi.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_sixt = 16
psixt = scores[scores['subject'] == partic_to_keep_sixt]
psixt
# Out:
#     subject experimenter  version    jnd  difficulty  interval  hit_rate  \
# 21       16           mw      1.1  5.875         1.0       425  0.928571
# 22       16           mw      1.1  5.875         1.0       500  0.880952
# 23       16           mw      1.1  5.875         1.0       575  0.976190
# 24       16           mw      1.1  5.875         0.5       425  0.880952
# 25       16           mw      1.1  5.875         0.5       500  0.880952
# 26       16           mw      1.1  5.875         0.5       575  0.880952
#
#      fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 21  0.166667     0.900          0.450  2.432655 -0.248906  1.175
# 22  0.166667     0.875          0.475  2.147183 -0.106170  1.500
# 23  0.071429     0.975          0.475  3.445986 -0.257759  1.175
# 24  0.404762     0.750          0.350  1.420802 -0.469360  1.700
# 25  0.404762     0.750          0.350  1.420802 -0.469360  1.575
# 26  0.357143     0.775          0.375  1.545867 -0.406827  1.400

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = psixt[psixt.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = psixt[psixt.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_sevt = 17
psevt = scores[scores['subject'] == partic_to_keep_sevt]
psevt
# Out:
#     subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 27       17           EM      1.1  5.0625         1.0       425  0.547619
# 28       17           EM      1.1  5.0625         1.0       500  0.785714
# 29       17           EM      1.1  5.0625         1.0       575  0.547619
# 30       17           EM      1.1  5.0625         0.5       425  0.690476
# 31       17           EM      1.1  5.0625         0.5       500  0.738095
# 32       17           EM      1.1  5.0625         0.5       575  0.547619
#
#      fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 27  0.119048     0.725          0.675  1.299409  0.530057  1.500
# 28  0.071429     0.875          0.575  2.256872  0.336798  1.375
# 29  0.071429     0.750          0.700  1.584882  0.672793  1.775
# 30  0.500000     0.600          0.400  0.497201 -0.248600  1.950
# 31  0.404762     0.675          0.425  0.878525 -0.198222  2.050
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_eigt = 18
peigt = scores[scores['subject'] == partic_to_keep_eigt]
peigt
# Out:
#     subject experimenter  version      jnd  difficulty  interval  hit_rate  \
# 33       18           EM      1.1  14.9375         1.0       425  0.690476
# 34       18           EM      1.1  14.9375         1.0       500  0.595238
# 35       18           EM      1.1  14.9375         1.0       575  0.642857
# 36       18           EM      1.1  14.9375         0.5       425  0.785714
# 37       18           EM      1.1  14.9375         0.5       500  0.928571
# 38       18           EM      1.1  14.9375         0.5       575  0.738095
#
#      fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 33  0.214286     0.750          0.550  1.288839  0.147219  1.700
# 34  0.071429     0.775          0.675  1.706274  0.612097  1.550
# 35  0.071429     0.800          0.650  1.831340  0.549564  2.025
# 36  0.547619     0.625          0.325  0.671990 -0.455643  2.225
# 37  0.404762     0.775          0.325  1.706274 -0.612097  2.850
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_nint = 19
pnint = scores[scores['subject'] == partic_to_keep_nint]
pnint
# Out:
#     subject experimenter  version      jnd  difficulty  interval  hit_rate  \
# 39       19          OMR      1.1  41.4375         1.0       425  0.404762
# 40       19          OMR      1.1  41.4375         1.0       500  0.452381
# 41       19          OMR      1.1  41.4375         1.0       575  0.547619
# 42       19          OMR      1.1  41.4375         0.5       425  0.738095
# 43       19          OMR      1.1  41.4375         0.5       500  0.690476
# 44       19          OMR      1.1  41.4375         0.5       575  0.500000
#
#      fa_rate  accuracy  perc_resp_low    dprime             C     rt
# 39  0.404762     0.500          0.600  0.000000  2.410404e-01  0.675
# 40  0.357143     0.550          0.600  0.246458  2.428772e-01  0.600
# 41  0.357143     0.600          0.550  0.485754  1.232291e-01  0.650
# 42  0.261905     0.750          0.500  1.274968 -1.110223e-16  0.625
# 43  0.452381     0.625          0.425  0.616849 -1.887762e-01  0.625
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_tw = 20
ptw = scores[scores['subject'] == partic_to_keep_tw]
ptw
# Out:
#     subject experimenter  version      jnd  difficulty  interval  hit_rate  \
# 48       20          OMR      1.1  20.4375         1.0       425  0.642857
# 49       20          OMR      1.1  20.4375         1.0       500  0.785714
# 50       20          OMR      1.1  20.4375         1.0       575  0.690476
# 51       20          OMR      1.1  20.4375         0.5       425  0.785714
# 52       20          OMR      1.1  20.4375         0.5       500  0.738095
# 53       20          OMR      1.1  20.4375         0.5       575  0.738095
#
#      fa_rate  accuracy  perc_resp_low    dprime             C     rt
# 48  0.119048     0.775          0.625  1.545867  4.068274e-01  0.600
# 49  0.071429     0.875          0.575  2.256872  3.367976e-01  0.450
# 50  0.023810     0.850          0.650  2.477953  7.417759e-01  0.750
# 51  0.309524     0.750          0.450  1.288839 -1.472190e-01  0.950
# 52  0.261905     0.750          0.500  1.274968 -1.110223e-16  0.675
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twon = 21
ptwon = scores[scores['subject'] == partic_to_keep_twon]
ptwon
# Out:
#     subject experimenter  version      jnd  difficulty  interval  hit_rate  \
# 54       21          OMR      1.1  38.6875         1.0       425  0.738095
# 55       21          OMR      1.1  38.6875         1.0       500  0.785714
# 56       21          OMR      1.1  38.6875         1.0       575  0.595238
# 57       21          OMR      1.1  38.6875         0.5       425  0.357143
# 58       21          OMR      1.1  38.6875         0.5       500  0.357143
# 59       21          OMR      1.1  38.6875         0.5       575  0.261905
#
#      fa_rate  accuracy  perc_resp_low    dprime             C     rt
# 54  0.547619     0.600          0.350  0.517836 -3.785661e-01  1.075
# 55  0.500000     0.650          0.350  0.791639 -3.958193e-01  1.150
# 56  0.404762     0.600          0.500  0.482081 -0.000000e+00  1.400
# 57  0.642857     0.350          0.500 -0.732213 -8.326673e-17  1.175
# 58  0.880952     0.225          0.375 -1.545867 -4.068274e-01  1.350
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twtwo = 22
ptwtwo = scores[scores['subject'] == partic_to_keep_twtwo]
ptwtwo
# Out:
#     subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 60       22          JKP      1.1  10.125         1.0       425  0.880952
# 61       22          JKP      1.1  10.125         1.0       500  0.785714
# 62       22          JKP      1.1  10.125         1.0       575  0.928571
# 63       22          JKP      1.1  10.125         0.5       425  0.690476
# 64       22          JKP      1.1  10.125         0.5       500  0.500000
# 65       22          JKP      1.1  10.125         0.5       575  0.547619
#
#      fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 60  0.023810     0.950          0.550  3.160514  0.400496  0.900
# 61  0.023810     0.900          0.600  2.772391  0.594557  1.050
# 62  0.023810     0.975          0.525  3.445986  0.257759  0.775
# 63  0.309524     0.700          0.500  0.994401 -0.000000  1.575
# 64  0.071429     0.725          0.725  1.465234  0.732617  1.600
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twth = 23
ptwth = scores[scores['subject'] == partic_to_keep_twth]
ptwth
# Out:
#     subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 66       23           EM      1.1  4.1875         1.0       425  0.928571
# 67       23           EM      1.1  4.1875         1.0       500  0.738095
# 68       23           EM      1.1  4.1875         1.0       575  0.833333
# 69       23           EM      1.1  4.1875         0.5       425  0.690476
# 70       23           EM      1.1  4.1875         0.5       500  0.690476
# 71       23           EM      1.1  4.1875         0.5       575  0.547619
#
#      fa_rate  accuracy  perc_resp_low    dprime             C     rt
# 66  0.309524     0.825          0.375  1.962434 -4.840166e-01  0.850
# 67  0.166667     0.800          0.550  1.604906  1.649687e-01  0.975
# 68  0.119048     0.875          0.525  2.147183  1.061698e-01  0.775
# 69  0.642857     0.525          0.325  0.131094 -4.316535e-01  1.000
# 70  0.452381     0.625          0.425  0.616849 -1.887762e-01  1.150
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twfo = 24
ptwfo = scores[scores['subject'] == partic_to_keep_twfo]
ptwfo
# Out:
#     subject experimenter  version   jnd  difficulty  interval  hit_rate  \
# 72       24           EM      1.1  7.75         1.0       425  0.976190
# 73       24           EM      1.1  7.75         1.0       500  0.928571
# 74       24           EM      1.1  7.75         1.0       575  0.928571
# 75       24           EM      1.1  7.75         0.5       425  0.928571
# 76       24           EM      1.1  7.75         0.5       500  0.976190
# 77       24           EM      1.1  7.75         0.5       575  0.928571
#
#      fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 72  0.119048     0.950          0.450  3.160514 -0.400496  0.750
# 73  0.119048     0.925          0.475  2.644995 -0.142736  1.025
# 74  0.214286     0.875          0.425  2.256872 -0.336798  0.950
# 75  0.261905     0.850          0.400  2.102718 -0.413875  0.925
# 76  0.214286     0.900          0.400  2.772391 -0.594557  1.150
# 77  0.119048     0.925          0.475  2.644995 -0.142736  0.875

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twfi = 25
ptwfi = scores[scores['subject'] == partic_to_keep_twfi]
ptwfi
# Out:
#     subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 78       25          JKP      1.1  11.375         1.0       425  0.928571
# 79       25          JKP      1.1  11.375         1.0       500  0.976190
# 80       25          JKP      1.1  11.375         1.0       575  0.976190
# 81       25          JKP      1.1  11.375         0.5       425  0.880952
# 82       25          JKP      1.1  11.375         0.5       500  0.928571
# 83       25          JKP      1.1  11.375         0.5       575  0.785714
#
#      fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 78  0.023810     0.975          0.525  3.445986  0.257759  0.650
# 79  0.071429     0.975          0.475  3.445986 -0.257759  0.700
# 80  0.023810     1.000          0.500  3.961505 -0.000000  0.825
# 81  0.166667     0.875          0.475  2.147183 -0.106170  1.200
# 82  0.071429     0.950          0.500  2.930468 -0.000000  1.100
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twsi = 26
ptwsi = scores[scores['subject'] == partic_to_keep_twsi]
ptwsi
# Out:
#     subject experimenter  version   jnd  difficulty  interval  hit_rate  \
# 84       26          OMR      1.1  4.25         1.0       425  0.833333
# 85       26          OMR      1.1  4.25         1.0       500  0.738095
# 86       26          OMR      1.1  4.25         1.0       575  0.690476
# 87       26          OMR      1.1  4.25         0.5       425  0.642857
# 88       26          OMR      1.1  4.25         0.5       500  0.595238
# 89       26          OMR      1.1  4.25         0.5       575  0.690476
#
#      fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 84  0.452381     0.700          0.350  1.087070 -0.423887  1.400
# 85  0.309524     0.725          0.475  1.134685 -0.070142  1.225
# 86  0.071429     0.825          0.625  1.962434  0.484017  1.400
# 87  0.738095     0.450          0.300 -0.271378 -0.501795  1.525
# 88  0.404762     0.600          0.500  0.482081 -0.000000  1.850
# 89  0.404762     0.650          0.450  0.738241 -0.128080  2.025

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twsev = 27
ptwsev = scores[scores['subject'] == partic_to_keep_twsev]
ptwsev
# Out:
#     subject experimenter  version      jnd  difficulty  interval  hit_rate  \
# 90       27          OMR      1.1  13.0625         1.0       425  0.880952
# 91       27          OMR      1.1  13.0625         1.0       500  0.880952
# 92       27          OMR      1.1  13.0625         1.0       575  0.833333
# 93       27          OMR      1.1  13.0625         0.5       425  0.690476
# 94       27          OMR      1.1  13.0625         0.5       500  0.880952
# 95       27          OMR      1.1  13.0625         0.5       575  0.785714
#
#      fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 90  0.023810     0.950          0.550  3.160514  0.400496  0.675
# 91  0.071429     0.925          0.525  2.644995  0.142736  0.975
# 92  0.023810     0.925          0.575  2.948174  0.506665  0.700
# 93  0.261905     0.725          0.525  1.134685  0.070142  0.975
# 94  0.357143     0.775          0.375  1.545867 -0.406827  1.050
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twei = 28
ptwei = scores[scores['subject'] == partic_to_keep_twei]
ptwei
# Out:
#      subject experimenter  version    jnd  difficulty  interval  hit_rate  \
# 96        28          OMR      1.1  2.875         1.0       425  0.404762
# 97        28          OMR      1.1  2.875         1.0       500  0.500000
# 98        28          OMR      1.1  2.875         1.0       575  0.452381
# 99        28          OMR      1.1  2.875         0.5       425  0.928571
# 100       28          OMR      1.1  2.875         0.5       500  0.833333
# 101       28          OMR      1.1  2.875         0.5       575  0.880952
#
#       fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 96   0.214286     0.600          0.700  0.550598  0.516340  1.300
# 97   0.309524     0.600          0.600  0.497201  0.248600  1.125
# 98   0.214286     0.625          0.675  0.671990  0.455643  1.250
# 99   0.547619     0.700          0.250  1.345586 -0.792441  1.250
# 100  0.595238     0.625          0.275  0.726381 -0.604231  1.225
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twei = 28
ptwei = scores[scores['subject'] == partic_to_keep_twei]
ptwei
# Out:
#      subject experimenter  version    jnd  difficulty  interval  hit_rate  \
# 96        28          OMR      1.1  2.875         1.0       425  0.404762
# 97        28          OMR      1.1  2.875         1.0       500  0.500000
# 98        28          OMR      1.1  2.875         1.0       575  0.452381
# 99        28          OMR      1.1  2.875         0.5       425  0.928571
# 100       28          OMR      1.1  2.875         0.5       500  0.833333
# 101       28          OMR      1.1  2.875         0.5       575  0.880952
#
#       fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 96   0.214286     0.600          0.700  0.550598  0.516340  1.300
# 97   0.309524     0.600          0.600  0.497201  0.248600  1.125
# 98   0.214286     0.625          0.675  0.671990  0.455643  1.250
# 99   0.547619     0.700          0.250  1.345586 -0.792441  1.250
# 100  0.595238     0.625          0.275  0.726381 -0.604231  1.225
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twni = 29
ptwni = scores[scores['subject'] == partic_to_keep_twni]
ptwni
# Out:
#      subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 102       29          OMR      1.1  8.8125         1.0       425  0.500000
# 103       29          OMR      1.1  8.8125         1.0       500  0.690476
# 104       29          OMR      1.1  8.8125         1.0       575  0.642857
# 105       29          OMR      1.1  8.8125         0.5       425  0.357143
# 106       29          OMR      1.1  8.8125         0.5       500  0.404762
# 107       29          OMR      1.1  8.8125         0.5       575  0.309524
#
#       fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 102  0.023810     0.750          0.750  1.980752  0.990376  1.525
# 103  0.119048     0.800          0.600  1.676962  0.341280  1.150
# 104  0.119048     0.775          0.625  1.545867  0.406827  1.600
# 105  0.214286     0.575          0.725  0.425532  0.578872  1.275
# 106  0.452381     0.475          0.575 -0.121392  0.180344  2.925
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thir = 30
pthir = scores[scores['subject'] == partic_to_keep_thir]
pthir
# Out:
#      subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 111       30           EM      1.1  4.6875         1.0       425  0.785714
# 112       30           EM      1.1  4.6875         1.0       500  0.642857
# 113       30           EM      1.1  4.6875         1.0       575  0.500000
# 114       30           EM      1.1  4.6875         0.5       425  0.500000
# 115       30           EM      1.1  4.6875         0.5       500  0.357143
# 116       30           EM      1.1  4.6875         0.5       575  0.404762
#
#       fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 111  0.357143     0.725          0.425  1.157745 -0.212766  1.425
# 112  0.119048     0.775          0.625  1.545867  0.406827  1.775
# 113  0.166667     0.675          0.675  0.967422  0.483711  1.575
# 114  0.071429     0.725          0.725  1.465234  0.732617  1.075
# 115  0.309524     0.525          0.675  0.131094  0.431653  1.625
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thiron = 31
pthiron = scores[scores['subject'] == partic_to_keep_thiron]
pthiron
# Out:
#      subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 117       31          OMR      1.1  6.6875         1.0       425  0.928571
# 118       31          OMR      1.1  6.6875         1.0       500  0.880952
# 119       31          OMR      1.1  6.6875         1.0       575  0.928571
# 120       31          OMR      1.1  6.6875         0.5       425  0.357143
# 121       31          OMR      1.1  6.6875         0.5       500  0.833333
# 122       31          OMR      1.1  6.6875         0.5       575  0.738095
#
#       fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 117  0.119048     0.925          0.475  2.644995 -0.142736  0.875
# 118  0.023810     0.950          0.550  3.160514  0.400496  0.950
# 119  0.071429     0.950          0.500  2.930468 -0.000000  1.025
# 120  0.166667     0.600          0.750  0.601315  0.666764  1.650
# 121  0.214286     0.825          0.475  1.759060 -0.087891  2.075
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thirtw = 32
pthirtw = scores[scores['subject'] == partic_to_keep_thirtw]
pthirtw
# Out:
#      subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 123       32           EM      1.1  5.9375         1.0       425  0.880952
# 124       32           EM      1.1  5.9375         1.0       500  0.690476
# 125       32           EM      1.1  5.9375         1.0       575  0.642857
# 126       32           EM      1.1  5.9375         0.5       425  0.785714
# 127       32           EM      1.1  5.9375         0.5       500  0.738095
# 128       32           EM      1.1  5.9375         0.5       575  0.547619
#
#       fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 123  0.261905     0.825          0.425  1.817245 -0.271138  1.325
# 124  0.261905     0.725          0.525  1.134685  0.070142  1.150
# 125  0.071429     0.800          0.650  1.831340  0.549564  0.900
# 126  0.357143     0.725          0.425  1.157745 -0.212766  1.575
# 127  0.500000     0.625          0.375  0.637484 -0.318742  1.475
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thirth = 33
pthirth = scores[scores['subject'] == partic_to_keep_thirth]
pthirth
# Out:
#      subject experimenter  version    jnd  difficulty  interval  hit_rate  \
# 129       33          JKP      1.1  9.875         1.0       425  0.833333
# 130       33          JKP      1.1  9.875         1.0       500  0.976190
# 131       33          JKP      1.1  9.875         1.0       575  0.880952
# 132       33          JKP      1.1  9.875         0.5       425  0.595238
# 133       33          JKP      1.1  9.875         0.5       500  0.642857
# 134       33          JKP      1.1  9.875         0.5       575  0.642857
#
#       fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 129  0.214286     0.825          0.475  1.759060 -0.087891  0.825
# 130  0.071429     0.975          0.475  3.445986 -0.257759  0.725
# 131  0.023810     0.950          0.550  3.160514  0.400496  0.650
# 132  0.261905     0.675          0.575  0.878525  0.198222  1.025
# 133  0.261905     0.700          0.550  1.003591  0.135689  0.725
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thirfr = 34
pthirfr = scores[scores['subject'] == partic_to_keep_thirfr]
pthirfr
# Out:
#      subject experimenter  version    jnd  difficulty  interval  hit_rate  \
# 135       34           EM      1.1  7.625         1.0       425  0.595238
# 136       34           EM      1.1  7.625         1.0       500  0.595238
# 137       34           EM      1.1  7.625         1.0       575  0.880952
# 138       34           EM      1.1  7.625         0.5       425  0.738095
# 139       34           EM      1.1  7.625         0.5       500  0.833333
# 140       34           EM      1.1  7.625         0.5       575  0.880952
#
#       fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 135  0.071429     0.775          0.675  1.706274  0.612097  0.600
# 136  0.119048     0.750          0.650  1.420802  0.469360  0.800
# 137  0.309524     0.800          0.400  1.676962 -0.341280  0.700
# 138  0.309524     0.725          0.475  1.134685 -0.070142  0.775
# 139  0.452381     0.700          0.350  1.087070 -0.423887  0.800
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thirfi = 35
pthirfi = scores[scores['subject'] == partic_to_keep_thirfi]
pthirfi
# Out:
#      subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 141       35           EM      1.1  7.9375         1.0       425  0.976190
# 142       35           EM      1.1  7.9375         1.0       500  0.976190
# 143       35           EM      1.1  7.9375         1.0       575  0.928571
# 144       35           EM      1.1  7.9375         0.5       425  0.738095
# 145       35           EM      1.1  7.9375         0.5       500  0.880952
# 146       35           EM      1.1  7.9375         0.5       575  0.833333
#
#       fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 141  0.023810     1.000          0.500  3.961505 -0.000000  0.675
# 142  0.023810     1.000          0.500  3.961505 -0.000000  1.025
# 143  0.071429     0.950          0.500  2.930468 -0.000000  0.875
# 144  0.023810     0.875          0.625  2.618237  0.671634  0.875
# 145  0.309524     0.800          0.400  1.676962 -0.341280  1.175
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thirsix = 36
pthirsix = scores[scores['subject'] == partic_to_keep_thirsix]
pthirsix
# Out:
#      subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 147       36           EM      1.1  3.5625         1.0       425  0.928571
# 148       36           EM      1.1  3.5625         1.0       500  0.690476
# 149       36           EM      1.1  3.5625         1.0       575  0.690476
# 150       36           EM      1.1  3.5625         0.5       425  0.452381
# 151       36           EM      1.1  3.5625         0.5       500  0.547619
# 152       36           EM      1.1  3.5625         0.5       575  0.595238
#
#       fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 147  0.071429     0.950          0.500  2.930468 -0.000000  1.725
# 148  0.119048     0.800          0.600  1.676962  0.341280  2.175
# 149  0.119048     0.800          0.600  1.676962  0.341280  1.800
# 150  0.214286     0.625          0.675  0.671990  0.455643  2.075
# 151  0.309524     0.625          0.575  0.616849  0.188776  2.225
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thirsev = 37
pthirsev = scores[scores['subject'] == partic_to_keep_thirsev]
pthirsev
# Out:
#      subject experimenter  version      jnd  difficulty  interval  hit_rate  \
# 153       37          OMR      1.1  10.4375         1.0       425  0.738095
# 154       37          OMR      1.1  10.4375         1.0       500  0.785714
# 155       37          OMR      1.1  10.4375         1.0       575  0.690476
# 156       37          OMR      1.1  10.4375         0.5       425  0.833333
# 157       37          OMR      1.1  10.4375         0.5       500  0.833333
# 158       37          OMR      1.1  10.4375         0.5       575  0.833333
#
#       fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 153  0.452381     0.650          0.400  0.757132 -0.258918  1.500
# 154  0.166667     0.825          0.525  1.759060  0.087891  1.300
# 155  0.166667     0.775          0.575  1.464622  0.235110  1.050
# 156  0.595238     0.625          0.275  0.726381 -0.604231  1.600
# 157  0.690476     0.575          0.225  0.470221 -0.732311  1.200
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thirei = 38
pthirei = scores[scores['subject'] == partic_to_keep_thirei]
pthirei
# Out:
#      subject experimenter  version     jnd  difficulty  interval  hit_rate  \
# 159       38           mw      1.1  9.6875         1.0       425  0.642857
# 160       38           mw      1.1  9.6875         1.0       500  0.738095
# 161       38           mw      1.1  9.6875         1.0       575  0.500000
# 162       38           mw      1.1  9.6875         0.5       425  0.595238
# 163       38           mw      1.1  9.6875         0.5       500  0.357143
# 164       38           mw      1.1  9.6875         0.5       575  0.500000
#
#       fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 159  0.119048     0.775          0.625  1.545867  0.406827  1.525
# 160  0.023810     0.875          0.625  2.618237  0.671634  1.275
# 161  0.119048     0.700          0.700  1.179761  0.589881  1.550
# 162  0.166667     0.725          0.625  1.208462  0.363191  1.500
# 163  0.214286     0.575          0.725  0.425532  0.578872  1.575
# ...

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thirnin = 39
pthirnin = scores[scores['subject'] == partic_to_keep_thirnin]
pthirnin
# Out:
#      subject experimenter  version      jnd  difficulty  interval  hit_rate  \
# 165       39           MW      1.1  16.0625         1.0       425  0.928571
# 166       39           MW      1.1  16.0625         1.0       500  0.785714
# 167       39           MW      1.1  16.0625         1.0       575  0.833333
# 168       39           MW      1.1  16.0625         0.5       425  0.833333
# 169       39           MW      1.1  16.0625         0.5       500  0.880952
# 170       39           MW      1.1  16.0625         0.5       575  0.880952
#
#       fa_rate  accuracy  perc_resp_low    dprime         C     rt
# 165  0.166667     0.900          0.450  2.432655 -0.248906  0.775
# 166  0.071429     0.875          0.575  2.256872  0.336798  0.725
# 167  0.214286     0.825          0.475  1.759060 -0.087891  0.925
# 168  0.309524     0.775          0.425  1.464622 -0.235110  0.825
# 169  0.404762     0.750          0.350  1.420802 -0.469360  1.075
# ...

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = psevt[psevt.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = psevt[psevt.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = peigt[peigt.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = peigt[peigt.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pnint[pnint.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = pnint[pnint.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = ptw[ptw.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = ptw[ptw.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = ptwon[ptwon.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = ptwon[ptwon.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = ptwtwo[ptwtwo.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = ptwtwo[ptwtwo.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = ptwth[ptwth.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = ptwth[ptwth.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = ptwfo[ptwfo.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = ptwfo[ptwfo.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = ptwfi[ptwfi.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = ptwfi[ptwfi.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = ptwsi[ptwsi.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = ptwsi[ptwsi.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = ptwsev[ptwsev.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = ptwsev[ptwsev.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = ptwei[ptwei.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = ptwei[ptwei.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = ptwni[ptwni.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = ptwni[ptwni.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pthir[pthir.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = pthir[pthir.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pthiron[pthiron.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = pthiron[pthiron.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pthirtw[pthirtw.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = pthirtw[pthirtw.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pthirth[pthirth.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = pthirth[pthirth.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pthirfr[pthirfr.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = pthirfr[pthirfr.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pthirfi[pthirfi.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = pthirfi[pthirfi.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pthirsix[pthirsix.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = pthirsix[pthirsix.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pthirsev[pthirsev.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = pthirsev[pthirsev.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pthirei[pthirei.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = pthirei[pthirei.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])

# %%
sns.lineplot(x = 'interval', y = 'dprime', data = pthirnin[pthirnin.difficulty == 1])
sns.lineplot(x = 'interval', y = 'dprime', data = pthirnin[pthirnin.difficulty == 0.5])
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlim(410, 590)
plt.xticks([425, 500, 575], ['-15', '0', '+15'])
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
plt.legend(['Easy', 'Hard'])
