# %%
import matplotlib
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import os

# %%
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /Users/oliverinaldi/Documents/GitHub/IllusoryPitch/E1/analysis

# %%
import os

new_directory = "/Users/oliverinaldi/Documents/GitHub/IllusoryPitch/E1/data"
os.chdir(new_directory)

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_ten = 10
pten = scores[scores['subject'] == partic_to_keep_ten]
pten
# Out:
#    subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 0       10       3     -15  0.928571  0.071429     0.950          0.500
# 1       10       3       0  0.785714  0.119048     0.850          0.550
# 2       10       3      15  0.785714  0.071429     0.875          0.575
# 3       10       5     -15  0.928571  0.119048     0.925          0.475
# 4       10       5       0  0.880952  0.023810     0.950          0.550
# 5       10       5      15  0.928571  0.071429     0.950          0.500
#
#      dprime         C
# 0  2.930468 -0.000000
# 1  1.971400  0.194061
# 2  2.256872  0.336798
# 3  2.644995 -0.142736
# 4  3.160514  0.400496
# 5  2.930468 -0.000000

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_ele = 11
pele = scores[scores['subject'] == partic_to_keep_ele]
pele
# Out:
#     subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 6        11       3     -15  0.595238  0.071429     0.775          0.675
# 7        11       3       0  0.690476  0.023810     0.850          0.650
# 8        11       3      15  0.690476  0.023810     0.850          0.650
# 9        11       5     -15  0.928571  0.071429     0.950          0.500
# 10       11       5       0  0.976190  0.023810     1.000          0.500
# 11       11       5      15  0.976190  0.023810     1.000          0.500
#
#       dprime         C
# 6   1.706274  0.612097
# 7   2.477953  0.741776
# 8   2.477953  0.741776
# 9   2.930468 -0.000000
# 10  3.961505 -0.000000
# 11  3.961505 -0.000000

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = pten[pten.octave == 3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = pten[pten.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = pele[pele.octave == 3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = pten[pten.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twl = 12
ptwl = scores[scores['subject'] == partic_to_keep_twl]
ptwl
# Out:
#     subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 12       12       3     -15  0.976190  0.071429     0.975          0.475
# 13       12       3       0  0.976190  0.023810     1.000          0.500
# 14       12       3      15  0.976190  0.023810     1.000          0.500
# 15       12       5     -15  0.928571  0.071429     0.950          0.500
# 16       12       5       0  0.880952  0.071429     0.925          0.525
# 17       12       5      15  0.976190  0.023810     1.000          0.500
#
#       dprime         C
# 12  3.445986 -0.257759
# 13  3.961505 -0.000000
# 14  3.961505 -0.000000
# 15  2.930468 -0.000000
# 16  2.644995  0.142736
# 17  3.961505 -0.000000

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = ptwl[ptwl.octave == 3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = ptwl[ptwl.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thir = 13
pthir = scores[scores['subject'] == partic_to_keep_thir]
pthir
# Out:
#     subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 18       13       3     -15  0.166667  0.309524     0.425          0.775
# 19       13       3       0  0.119048  0.261905     0.425          0.825
# 20       13       3      15  0.452381  0.214286     0.625          0.675
# 21       13       5     -15  0.500000  0.357143     0.575          0.575
# 22       13       5       0  0.738095  0.404762     0.675          0.425
# 23       13       5      15  0.023810  0.119048     0.450          0.950
#
#       dprime         C
# 18 -0.470221  0.732311
# 19 -0.542277  0.908623
# 20  0.671990  0.455643
# 21  0.366106  0.183053
# 22  0.878525 -0.198222
# 23 -0.800991  1.580257

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = pthir[pthir.octave == 3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = pthir[pthir.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
pthir.dprime.mean()
# Out:
# 0.017188695874576183

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_for = 14
pfor = scores[scores['subject'] == partic_to_keep_for]
pfor
# Out:
#     subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 24       14       3     -15  0.500000  0.404762     0.550          0.550
# 25       14       3       0  0.500000  0.500000     0.500          0.500
# 26       14       3      15  0.214286  0.214286     0.500          0.800
# 27       14       5     -15  0.547619  0.214286     0.675          0.625
# 28       14       5       0  0.547619  0.309524     0.625          0.575
# 29       14       5      15  0.452381  0.357143     0.550          0.600
#
#       dprime         C
# 24  0.241040  0.120520
# 25  0.000000 -0.000000
# 26  0.000000  0.791639
# 27  0.911287  0.335995
# 28  0.616849  0.188776
# 29  0.246458  0.242877

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = pfor[pfor.octave == 3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = pfor[pfor.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_fi = 15
pfi = scores[scores['subject'] == partic_to_keep_fi]
pfi
# Out:
#     subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 30       15       3     -15  0.500000  0.500000     0.500          0.500
# 31       15       3       0  0.214286  0.500000     0.350          0.650
# 32       15       3      15  0.309524  0.214286     0.550          0.750
# 33       15       5     -15  0.595238  0.738095     0.425          0.325
# 34       15       5       0  0.595238  0.547619     0.525          0.425
# 35       15       5      15  0.309524  0.309524     0.500          0.700
#
#       dprime         C
# 30  0.000000 -0.000000
# 31 -0.791639  0.395819
# 32  0.294438  0.644420
# 33 -0.396444 -0.439262
# 34  0.121392 -0.180344
# 35  0.000000  0.497201

# %%
pfi.dprime.mean()
# Out:
# -0.1287086761519533

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = pfi[pfi.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = pfi[pfi.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_sixt = 16
psixt = scores[scores['subject'] == partic_to_keep_sixt]
psixt
# Out:
#     subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 36       16       3     -15  0.833333  0.642857     0.600          0.250
# 37       16       3       0  0.357143  0.119048     0.625          0.775
# 38       16       3      15  0.119048  0.023810     0.550          0.950
# 39       16       5     -15  0.880952  0.690476     0.600          0.200
# 40       16       5       0  0.547619  0.357143     0.600          0.550
# 41       16       5      15  0.642857  0.214286     0.725          0.575
#
#       dprime         C
# 36  0.601315 -0.666764
# 37  0.813655  0.772934
# 38  0.800991  1.580257
# 39  0.682561 -0.838481
# 40  0.485754  0.123229
# 41  1.157745  0.212766

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = psixt[psixt.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = psixt[psixt.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_sevt = 17
psevt = scores[scores['subject'] == partic_to_keep_sevt]
psevt
# Out:
#     subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 42       17       3     -15  0.785714  0.119048     0.850          0.550
# 43       17       3       0  0.833333  0.119048     0.875          0.525
# 44       17       3      15  0.738095  0.071429     0.850          0.600
# 45       17       5     -15  0.690476  0.023810     0.850          0.650
# 46       17       5       0  0.928571  0.023810     0.975          0.525
# 47       17       5      15  0.833333  0.119048     0.875          0.525
#
#       dprime         C
# 42  1.971400  0.194061
# 43  2.147183  0.106170
# 44  2.102718  0.413875
# 45  2.477953  0.741776
# 46  3.445986  0.257759
# 47  2.147183  0.106170

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_eigt = 18
peigt = scores[scores['subject'] == partic_to_keep_eigt]
peigt
# Out:
#     subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 48       18       3     -15  0.500000  0.357143     0.575          0.575
# 49       18       3       0  0.357143  0.119048     0.625          0.775
# 50       18       3      15  0.309524  0.119048     0.600          0.800
# 51       18       5     -15  0.642857  0.452381     0.600          0.450
# 52       18       5       0  0.642857  0.690476     0.475          0.325
# 53       18       5      15  0.547619  0.404762     0.575          0.525
#
#       dprime         C
# 48  0.366106  0.183053
# 49  0.813655  0.772934
# 50  0.682561  0.838481
# 51  0.485754 -0.123229
# 52 -0.131094 -0.431653
# 53  0.360689  0.060696

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_nint = 19
pnint = scores[scores['subject'] == partic_to_keep_nint]
pnint
# Out:
#     subject  octave  offset  hit_rate  fa_rate  accuracy  perc_resp_low  \
# 54       19       3     -15  0.976190  0.02381      1.00           0.50
# 55       19       3       0  0.976190  0.02381      1.00           0.50
# 56       19       3      15  0.976190  0.02381      1.00           0.50
# 57       19       5     -15  0.976190  0.02381      1.00           0.50
# 58       19       5       0  0.880952  0.02381      0.95           0.55
# 59       19       5      15  0.976190  0.02381      1.00           0.50
#
#       dprime         C
# 54  3.961505 -0.000000
# 55  3.961505 -0.000000
# 56  3.961505 -0.000000
# 57  3.961505 -0.000000
# 58  3.160514  0.400496
# 59  3.961505 -0.000000

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_tw = 20
ptw = scores[scores['subject'] == partic_to_keep_tw]
ptw
# Out:
#     subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 60       20       3     -15  0.404762  0.166667     0.625          0.725
# 61       20       3       0  0.547619  0.023810     0.775          0.725
# 62       20       3      15  0.404762  0.071429     0.675          0.775
# 63       20       5     -15  0.642857  0.452381     0.600          0.450
# 64       20       5       0  0.595238  0.071429     0.775          0.675
# 65       20       5      15  0.642857  0.071429     0.800          0.650
#
#       dprime         C
# 60  0.726381  0.604231
# 61  2.100401  0.930552
# 62  1.224193  0.853137
# 63  0.485754 -0.123229
# 64  1.706274  0.612097
# 65  1.831340  0.549564

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twon = 21
ptwon = scores[scores['subject'] == partic_to_keep_twon]
ptwon
# Out:
#     subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 66       21       3     -15  0.928571  0.214286     0.875          0.425
# 67       21       3       0  0.880952  0.071429     0.925          0.525
# 68       21       3      15  0.928571  0.023810     0.975          0.525
# 69       21       5     -15  0.976190  0.023810     1.000          0.500
# 70       21       5       0  0.976190  0.023810     1.000          0.500
# 71       21       5      15  0.976190  0.023810     1.000          0.500
#
#       dprime         C
# 66  2.256872 -0.336798
# 67  2.644995  0.142736
# 68  3.445986  0.257759
# 69  3.961505 -0.000000
# 70  3.961505 -0.000000
# 71  3.961505 -0.000000

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twtwo = 22
ptwtwo = scores[scores['subject'] == partic_to_keep_twtwo]
ptwtwo
# Out:
#     subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 72       22       3     -15  0.690476  0.785714     0.450          0.250
# 73       22       3       0  0.547619  0.500000     0.525          0.475
# 74       22       3      15  0.404762  0.690476     0.350          0.450
# 75       22       5     -15  0.738095  0.833333     0.450          0.200
# 76       22       5       0  0.547619  0.785714     0.375          0.325
# 77       22       5      15  0.547619  0.785714     0.375          0.325
#
#       dprime         C
# 72 -0.294438 -0.644420
# 73  0.119648 -0.059824
# 74 -0.738241 -0.128080
# 75 -0.329937 -0.802453
# 76 -0.671990 -0.455643
# 77 -0.671990 -0.455643

# %%
ptwtwo.dprime.mean()
# Out:
# -0.43115821385599135

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twth = 23
ptwth = scores[scores['subject'] == partic_to_keep_twth]
ptwth
# Out:
#     subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 78       23       3     -15  0.738095  0.309524     0.725          0.475
# 79       23       3       0  0.785714  0.404762     0.700          0.400
# 80       23       3      15  0.547619  0.261905     0.650          0.600
# 81       23       5     -15  0.785714  0.119048     0.850          0.550
# 82       23       5       0  0.880952  0.214286     0.850          0.450
# 83       23       5      15  0.833333  0.119048     0.875          0.525
#
#       dprime         C
# 78  1.134685 -0.070142
# 79  1.032679 -0.275299
# 80  0.757132  0.258918
# 81  1.971400  0.194061
# 82  1.971400 -0.194061
# 83  2.147183  0.106170

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twfo = 24
ptwfo = scores[scores['subject'] == partic_to_keep_twfo]
ptwfo
# Out:
#     subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 84       24       3     -15  0.833333  0.071429     0.900          0.550
# 85       24       3       0  0.690476  0.023810     0.850          0.650
# 86       24       3      15  0.690476  0.023810     0.850          0.650
# 87       24       5     -15  0.785714  0.023810     0.900          0.600
# 88       24       5       0  0.833333  0.023810     0.925          0.575
# 89       24       5      15  0.595238  0.023810     0.800          0.700
#
#       dprime         C
# 84  2.432655  0.248906
# 85  2.477953  0.741776
# 86  2.477953  0.741776
# 87  2.772391  0.594557
# 88  2.948174  0.506665
# 89  2.221793  0.869856

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twfi = 25
ptwfi = scores[scores['subject'] == partic_to_keep_twfi]
ptwfi
# Out:
#     subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 90       25       3     -15  0.880952  0.119048     0.900          0.500
# 91       25       3       0  0.880952  0.023810     0.950          0.550
# 92       25       3      15  0.928571  0.023810     0.975          0.525
# 93       25       5     -15  0.880952  0.214286     0.850          0.450
# 94       25       5       0  0.880952  0.166667     0.875          0.475
# 95       25       5      15  0.880952  0.119048     0.900          0.500
#
#       dprime         C
# 90  2.359522 -0.000000
# 91  3.160514  0.400496
# 92  3.445986  0.257759
# 93  1.971400 -0.194061
# 94  2.147183 -0.106170
# 95  2.359522 -0.000000

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twsi = 26
ptwsi = scores[scores['subject'] == partic_to_keep_twsi]
ptwsi
# Out:
#      subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 96        26       3     -15  0.595238  0.023810     0.800          0.700
# 97        26       3       0  0.357143  0.166667     0.600          0.750
# 98        26       3      15  0.357143  0.023810     0.675          0.825
# 99        26       5     -15  0.547619  0.500000     0.525          0.475
# 100       26       5       0  0.785714  0.500000     0.650          0.350
# 101       26       5      15  0.690476  0.452381     0.625          0.425
#
#        dprime         C
# 96   2.221793  0.869856
# 97   0.601315  0.666764
# 98   1.614646  1.173429
# 99   0.119648 -0.059824
# 100  0.791639 -0.395819
# 101  0.616849 -0.188776

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twsev = 27
ptwsev = scores[scores['subject'] == partic_to_keep_twsev]
ptwsev
# Out:
#      subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 102       27       3     -15  0.595238  0.214286     0.700          0.600
# 103       27       3       0  0.690476  0.214286     0.750          0.550
# 104       27       3      15  0.452381  0.166667     0.650          0.700
# 105       27       5     -15  0.785714  0.214286     0.800          0.500
# 106       27       5       0  0.595238  0.309524     0.650          0.550
# 107       27       5      15  0.547619  0.119048     0.725          0.675
#
#        dprime         C
# 102  1.032679  0.275299
# 103  1.288839  0.147219
# 104  0.847773  0.543535
# 105  1.583277 -0.000000
# 106  0.738241  0.128080
# 107  1.299409  0.530057

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twei = 28
ptwei = scores[scores['subject'] == partic_to_keep_twei]
ptwei
# Out:
#      subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 108       28       3     -15  0.928571  0.023810     0.975          0.525
# 109       28       3       0  0.928571  0.357143     0.800          0.350
# 110       28       3      15  0.880952  0.071429     0.925          0.525
# 111       28       5     -15  0.976190  0.309524     0.850          0.350
# 112       28       5       0  0.642857  0.119048     0.775          0.625
# 113       28       5      15  0.738095  0.023810     0.875          0.625
#
#        dprime         C
# 108  3.445986  0.257759
# 109  1.831340 -0.549564
# 110  2.644995  0.142736
# 111  2.477953 -0.741776
# 112  1.545867  0.406827
# 113  2.618237  0.671634

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twei = 28
ptwei = scores[scores['subject'] == partic_to_keep_twei]
ptwei
# Out:
#      subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 108       28       3     -15  0.928571  0.023810     0.975          0.525
# 109       28       3       0  0.928571  0.357143     0.800          0.350
# 110       28       3      15  0.880952  0.071429     0.925          0.525
# 111       28       5     -15  0.976190  0.309524     0.850          0.350
# 112       28       5       0  0.642857  0.119048     0.775          0.625
# 113       28       5      15  0.738095  0.023810     0.875          0.625
#
#        dprime         C
# 108  3.445986  0.257759
# 109  1.831340 -0.549564
# 110  2.644995  0.142736
# 111  2.477953 -0.741776
# 112  1.545867  0.406827
# 113  2.618237  0.671634

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_twni = 29
ptwni = scores[scores['subject'] == partic_to_keep_twni]
ptwni
# Out:
#      subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 114       29       3     -15  0.976190  0.166667     0.925          0.425
# 115       29       3       0  0.785714  0.023810     0.900          0.600
# 116       29       3      15  0.785714  0.166667     0.825          0.525
# 117       29       5     -15  0.976190  0.023810     1.000          0.500
# 118       29       5       0  0.880952  0.023810     0.950          0.550
# 119       29       5      15  0.928571  0.023810     0.975          0.525
#
#        dprime         C
# 114  2.948174 -0.506665
# 115  2.772391  0.594557
# 116  1.759060  0.087891
# 117  3.961505 -0.000000
# 118  3.160514  0.400496
# 119  3.445986  0.257759

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thir = 30
pthir = scores[scores['subject'] == partic_to_keep_thir]
pthir
# Out:
#      subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 120       30       3     -15  0.880952  0.166667     0.875          0.475
# 121       30       3       0  0.833333  0.166667     0.850          0.500
# 122       30       3      15  0.833333  0.023810     0.925          0.575
# 123       30       5     -15  0.976190  0.071429     0.975          0.475
# 124       30       5       0  0.928571  0.071429     0.950          0.500
# 125       30       5      15  0.880952  0.166667     0.875          0.475
#
#        dprime         C
# 120  2.147183 -0.106170
# 121  1.934843 -0.000000
# 122  2.948174  0.506665
# 123  3.445986 -0.257759
# 124  2.930468 -0.000000
# 125  2.147183 -0.106170

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thiron = 31
pthiron = scores[scores['subject'] == partic_to_keep_thiron]
pthiron
# Out:
#      subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 126       31       3     -15  0.738095  0.738095     0.500          0.250
# 127       31       3       0  0.547619  0.547619     0.500          0.450
# 128       31       3      15  0.500000  0.166667     0.675          0.675
# 129       31       5     -15  0.738095  0.642857     0.550          0.300
# 130       31       5       0  0.738095  0.547619     0.600          0.350
# 131       31       5      15  0.500000  0.500000     0.500          0.500
#
#        dprime         C
# 126  0.000000 -0.637484
# 127  0.000000 -0.119648
# 128  0.967422  0.483711
# 129  0.271378 -0.501795
# 130  0.517836 -0.378566
# 131  0.000000 -0.000000

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thirtw = 32
pthirtw = scores[scores['subject'] == partic_to_keep_thirtw]
pthirtw
# Out:
#      subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 132       32       3     -15  0.357143  0.261905     0.550          0.700
# 133       32       3       0  0.309524  0.261905     0.525          0.725
# 134       32       3      15  0.357143  0.309524     0.525          0.675
# 135       32       5     -15  0.928571  0.261905     0.850          0.400
# 136       32       5       0  0.738095  0.404762     0.675          0.425
# 137       32       5      15  0.595238  0.357143     0.625          0.525
#
#        dprime         C
# 132  0.271378  0.501795
# 133  0.140284  0.567342
# 134  0.131094  0.431653
# 135  2.102718 -0.413875
# 136  0.878525 -0.198222
# 137  0.607147  0.062533

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thirth = 33
pthirth = scores[scores['subject'] == partic_to_keep_thirth]
pthirth
# Out:
#      subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 138       33       3     -15  0.928571  0.547619     0.700          0.250
# 139       33       3       0  0.547619  0.214286     0.675          0.625
# 140       33       3      15  0.404762  0.023810     0.700          0.800
# 141       33       5     -15  0.880952  0.738095     0.575          0.175
# 142       33       5       0  0.785714  0.452381     0.675          0.375
# 143       33       5      15  0.357143  0.119048     0.625          0.775
#
#        dprime         C
# 138  1.345586 -0.792441
# 139  0.911287  0.335995
# 140  1.739712  1.110896
# 141  0.542277 -0.908623
# 142  0.911287 -0.335995
# 143  0.813655  0.772934

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thirfr = 34
pthirfr = scores[scores['subject'] == partic_to_keep_thirfr]
pthirfr
# Out:
#      subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 144       34       3     -15  0.309524  0.071429     0.625          0.825
# 145       34       3       0  0.690476  0.357143     0.675          0.475
# 146       34       3      15  0.547619  0.214286     0.675          0.625
# 147       34       5     -15  0.785714  0.309524     0.750          0.450
# 148       34       5       0  0.690476  0.404762     0.650          0.450
# 149       34       5      15  0.642857  0.309524     0.675          0.525
#
#        dprime         C
# 144  0.968033  0.981217
# 145  0.863307 -0.065547
# 146  0.911287  0.335995
# 147  1.288839 -0.147219
# 148  0.738241 -0.128080
# 149  0.863307  0.065547

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thirfi = 35
pthirfi = scores[scores['subject'] == partic_to_keep_thirfi]
pthirfi
# Out:
#      subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 150       35       3     -15  0.976190  0.833333     0.575          0.075
# 151       35       3       0  0.738095  0.785714     0.475          0.225
# 152       35       3      15  0.023810  0.119048     0.450          0.950
# 153       35       5     -15  0.976190  0.976190     0.500          0.000
# 154       35       5       0  0.833333  0.738095     0.550          0.200
# 155       35       5      15  0.309524  0.119048     0.600          0.800
#
#        dprime         C
# 150  1.013331 -1.474087
# 151 -0.154154 -0.714561
# 152 -0.800991  1.580257
# 153  0.000000 -1.980752
# 154  0.329937 -0.802453
# 155  0.682561  0.838481

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thirsix = 36
pthirsix = scores[scores['subject'] == partic_to_keep_thirsix]
pthirsix
# Out:
#      subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 156       36       3     -15  0.976190  0.452381     0.775          0.275
# 157       36       3       0  0.928571  0.119048     0.925          0.475
# 158       36       3      15  0.833333  0.071429     0.900          0.550
# 159       36       5     -15  0.833333  0.357143     0.750          0.400
# 160       36       5       0  0.928571  0.214286     0.875          0.425
# 161       36       5      15  0.642857  0.119048     0.775          0.625
#
#        dprime         C
# 156  2.100401 -0.930552
# 157  2.644995 -0.142736
# 158  2.432655  0.248906
# 159  1.333528 -0.300658
# 160  2.256872 -0.336798
# 161  1.545867  0.406827

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thirsev = 37
pthirsev = scores[scores['subject'] == partic_to_keep_thirsev]
pthirsev
# Out:
#      subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 162       37       3     -15  0.928571  0.833333     0.550          0.100
# 163       37       3       0  0.500000  0.166667     0.675          0.675
# 164       37       3      15  0.404762  0.166667     0.625          0.725
# 165       37       5     -15  0.976190  0.785714     0.600          0.100
# 166       37       5       0  0.500000  0.452381     0.525          0.525
# 167       37       5      15  0.309524  0.119048     0.600          0.800
#
#        dprime         C
# 162  0.497812 -1.216328
# 163  0.967422  0.483711
# 164  0.726381  0.604231
# 165  1.189114 -1.386196
# 166  0.119648  0.059824
# 167  0.682561  0.838481

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thirei = 38
pthirei = scores[scores['subject'] == partic_to_keep_thirei]
pthirei
# Out:
#      subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 168       38       3     -15  0.690476  0.119048     0.800          0.600
# 169       38       3       0  0.738095  0.214286     0.775          0.525
# 170       38       3      15  0.785714  0.357143     0.725          0.425
# 171       38       5     -15  0.785714  0.119048     0.850          0.550
# 172       38       5       0  0.785714  0.214286     0.800          0.500
# 173       38       5      15  0.833333  0.166667     0.850          0.500
#
#        dprime         C
# 168  1.676962  0.341280
# 169  1.429123  0.077077
# 170  1.157745 -0.212766
# 171  1.971400  0.194061
# 172  1.583277 -0.000000
# 173  1.934843 -0.000000

# %%
scores = pd.read_csv("scores.csv")
partic_to_keep_thirnin = 39
pthirnin = scores[scores['subject'] == partic_to_keep_thirnin]
pthirnin
# Out:
#      subject  octave  offset  hit_rate   fa_rate  accuracy  perc_resp_low  \
# 174       39       3     -15  0.928571  0.023810     0.975          0.525
# 175       39       3       0  0.785714  0.119048     0.850          0.550
# 176       39       3      15  0.690476  0.071429     0.825          0.625
# 177       39       5     -15  0.738095  0.357143     0.700          0.450
# 178       39       5       0  0.833333  0.119048     0.875          0.525
# 179       39       5      15  0.690476  0.119048     0.800          0.600
#
#        dprime         C
# 174  3.445986  0.257759
# 175  1.971400  0.194061
# 176  1.962434  0.484017
# 177  1.003591 -0.135689
# 178  2.147183  0.106170
# 179  1.676962  0.341280

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = psevt[psevt.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = psevt[psevt.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = peigt[peigt.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = peigt[peigt.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = pnint[pnint.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = pnint[pnint.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = ptw[ptw.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = ptw[ptw.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = ptwon[ptwon.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = ptwon[ptwon.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = ptwtwo[ptwtwo.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = ptwtwo[ptwtwo.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = ptwth[ptwth.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = ptwth[ptwth.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = ptwfo[ptwfo.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = ptwfo[ptwfo.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = ptwfi[ptwfi.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = ptwfi[ptwfi.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = ptwsi[ptwsi.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = ptwsi[ptwsi.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = ptwsev[ptwsev.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = ptwsev[ptwsev.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = ptwei[ptwei.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = ptwei[ptwei.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = ptwni[ptwni.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = ptwni[ptwni.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = pthir[pthir.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = pthir[pthir.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = pthiron[pthiron.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = pthiron[pthiron.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = pthirtw[pthirtw.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = pthirtw[pthirtw.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = pthirth[pthirth.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = pthirth[pthirth.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = pthirfr[pthirfr.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = pthirfr[pthirfr.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = pthirfi[pthirfi.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = pthirfi[pthirfi.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = pthirsix[pthirsix.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = pthirsix[pthirsix.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = pthirsev[pthirsev.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = pthirsev[pthirsev.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = pthirei[pthirei.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = pthirei[pthirei.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')

# %%
sns.lineplot(x = 'offset', y = 'dprime', data = pthirnin[pthirnin.octave ==  3], label = 'A3 (220 Hz)')
sns.lineplot(x = 'offset', y = 'dprime', data = pthirnin[pthirnin.octave == 5], label = 'A5 (880 Hz)')
plt.axhline(0, ls='-.', c='black', alpha=.5)
 
  
plt.xlabel('Probe Timing Offset (%)')
plt.ylabel('Sensitivity ($d\prime$)')
# Out:
# Text(0, 0.5, 'Sensitivity ($d\\prime$)')
